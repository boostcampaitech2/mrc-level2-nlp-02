# %%
import subprocess
subprocess.call(['bash', 'run_elasticsearch.sh'])
# Out:
# WARNING: A terminally deprecated method in java.lang.System has been called
# WARNING: System::setSecurityManager has been called by org.elasticsearch.bootstrap.Elasticsearch (file:/opt/ml/elastic_search/elasticsearch-7.15.1/lib/elasticsearch-7.15.1.jar)
# WARNING: Please consider reporting this to the maintainers of org.elasticsearch.bootstrap.Elasticsearch
# WARNING: System::setSecurityManager will be removed in a future release
# 2021-10-22 01:45:05,494 main ERROR RollingFileManager (/opt/ml/elastic_search/elasticsearch-7.15.1/logs/elasticsearch_server.json) java.io.FileNotFoundException: /opt/ml/elastic_search/elasticsearch-7.15.1/logs/elasticsearch_server.json (Permission denied) java.io.FileNotFoundException: /opt/ml/elastic_search/elasticsearch-7.15.1/logs/elasticsearch_server.json (Permission denied)
# 	at java.base/java.io.FileOutputStream.open0(Native Method)
# 	at java.base/java.io.FileOutputStream.open(FileOutputStream.java:293)
# ...
